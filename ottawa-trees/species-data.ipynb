# %% [markdown]
# # Species Data
#
# ## Project Description
#
# In this I will be extracting/scraping and cleaning up some data about tree species for use in the Tree Stats book.
#
# ## Sources
# - treecanada.ca

# %%
from bs4 import BeautifulSoup
import csv
import nltk
import pandas as pd
import requests

url = "https://treecanada.ca/resources/trees-of-canada/"
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:136.0) Gecko/20100101 Firefox/136.0"}

res = requests.get(
    url.strip(), 
    headers=headers, 
    timeout=10
)

soup = BeautifulSoup(res.content, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 from bs4 import BeautifulSoup
#       2 import csv
# ----> 3 import nltk
#       4 import pandas as pd
#       5 import requests
#
# ModuleNotFoundError: No module named 'nltk'

# %%
table = soup.find_all('table')[0]
rows = table.find_all('tr')

HEADERS = [
    "species", 
    "latin_species", 
    "variety", 
    "origin_canada", 
    "edible"
]

with open('data/species-data.csv', 'w', newline='',encoding='utf-8') as outfile:
    writer = csv.writer(outfile)
    writer.writerow(HEADERS)
    
    for row in rows[1:]:
        cells = row.find_all('td')
        names = cells[0].text.strip()

        common_name = names.split("(")[0]
        latin_name = names[names.find("(")+1:names.find(")")]
        variety = cells[1].text.strip()
        origin = cells[2].text.strip()
        edible = "Edible" if bool(cells[3].text.strip()) else "Inedible"

        print(nltk.word_tokenize(common_name))

        data_out = [common_name, latin_name, variety, origin, edible]
        writer.writerow(data_out)
# Out:
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Edible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Edible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Edible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Edible
# Edible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Edible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Edible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible
# Inedible

# %%
species = pd.read_csv("data/species-data.csv")
species
# Out:
#                     species               latin_species    variety  \
# 0                 Ailanthus         Ailanthus altissima  Deciduous
# 1        Alaska paper birch          Betula neoalaskana  Deciduous
# 2    Alternate-leaf dogwood         Cornus alternifolia  Deciduous
# 3            American beech           Fagus grandifolia  Deciduous
# 4         American chestnut            Castanea dentata  Deciduous
# ..                      ...                         ...        ...
# 309             Witch-hazel        Hamamelis virginiana  Deciduous
# 310            Yellow birch       Betula alleghaniensis  Deciduous
# 311            Yellow-cedar  Chamaecyparis nootkatensis    Conifer
# 312     Yellow-Twig Dogwood              Cornus sericea  Deciduous
# 313             Yellow-wood            Cladrastis lutea  Deciduous
#
#     origin_canada    edible
# 0     Naturalized  Inedible
# 1          Native  Inedible
# 2          Native  Inedible
# 3          Native  Inedible
# 4          Native    Edible
# ..            ...       ...
# 309        Native  Inedible
# 310        Native  Inedible
# 311        Native  Inedible
# 312   Naturalized  Inedible
# 313    Introduced  Inedible
#
# [314 rows x 5 columns]
